# %% [markdown]
# # load a `csv` file into sql

# %% [markdown]
# ### Import the necessary libraries

# %%
import pymysql
import sqlalchemy as alch 
from getpass import getpass
import pandas as pd
import os
import pandas as pd
from sqlalchemy import create_engine, text

# %% [markdown]
# ### 1. FROM workbench: create a database with the name `shoes`

# %%
# Set the environment variable
os.environ['DB_PASSWORD'] = db_password

# Check if the environment variable is set
if 'DB_PASSWORD' in os.environ:
    print("DB_PASSWORD is set:")
else:
    print("DB_PASSWORD is not set.")
# Out:
# DB_PASSWORD is set:

# %% [markdown]
# ### 2. Establish a connection to your database through python

# %%
engine = create_engine(f'mysql+pymysql://root:{db_password}@localhost')

with engine.connect() as connection:
    connection.execute(text("CREATE DATABASE IF NOT EXISTS shoes CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci"))

# %% [markdown]
# ### 3. Load the table **into pandas as a df**: from the datasets folder, get the `murallas.csv` file

# %%
murallas = pd.read_csv('../lab-sql-seeding-db/data/murallas.csv')

# %%
murallas
# Out:
#     Unnamed: 0                                              names  \
# 0            0  Zapatilla Mujer Reebok Classic Leather SP   Bl...
# 1            1              Zapatilla Nike Zoom Air Fire   Blanco
# 2            2                                    New Balance 530
# 3            3              Zapatillla  New Balance CT302   Beige
# 4            4            Zapatilla Mujer New Balance 327   Beige
# 5            5                                    New Balance 327
# 6            6                                    New Balance 327
# 7            7                                    New Balance 610
# 8            8  Zapatilla  Converse All Star Lift High Water-R...
# 9            9  Zapatilla  Converse All Star Hi Water-Repellen...
# 10          10                   Zapatilla Converse Lift Hi Suede
# 11          11      Zapatilla  Converse CTAS Lugged 2.0 Hi   Gris
# 12          12  Zapatilla  Converse Chuck Taylor  Lift Hi  Marrón
# 13          13  Zapatilla Mujer Converse Move Plat Stripe Knit...
# 14          14  Zapatilla Converse Chuck Taylor All Star Lift ...
# 15          15          Zapatilla Converse Run Star Hike Hi  Gris
# 16          16       Zapatilla  Converse Run Star Hike Hi  Marrón
# 17          17  Zapatilla Converse Lugged 2.0 Caunter Climate ...
# 18          18                           Zapatilla Vans Old Skool
# 19          19                   Vans Old Skool Platform   Blanco
# 20          20               Zapatilla  Vans Sk8-Hi Mte-1   Negro
# 21          21            Zapatilla  Puma Carina Lift TW   Blanco
# 22          22                     Zapatilla  Puma Mayze   Blanco
# 23          23                 Zapatillas  Puma Rider FV   Blanco
#
#           brand   price                                              links
# 0        ADIDAS   90.00  https://www.murallasport.com/producto/5477-zap...
# 1          NIKE  119.99  https://www.murallasport.com/producto/5998-zap...
# 2   NEW BALANCE  110.00  https://www.murallasport.com/producto/6229-new...
# 3   NEW BALANCE  110.00  https://www.murallasport.com/producto/5330-zap...
# 4   NEW BALANCE  114.00  https://www.murallasport.com/producto/5473-zap...
# 5   NEW BALANCE  120.00  https://www.murallasport.com/producto/5948-new...
# 6   NEW BALANCE  120.00  https://www.murallasport.com/producto/5949-new...
# 7   NEW BALANCE  120.00  https://www.murallasport.com/producto/6045-new...
# 8      CONVERSE   79.95  https://www.murallasport.com/producto/5584-zap...
# 9      CONVERSE   80.00  https://www.murallasport.com/producto/5853-zap...
# 10     CONVERSE   84.95  https://www.murallasport.com/producto/5578-zap...
# 11     CONVERSE   85.00  https://www.murallasport.com/producto/5586-zap...
# 12     CONVERSE   90.00  https://www.murallasport.com/producto/5608-zap...
# 13     CONVERSE   95.00  https://www.murallasport.com/producto/5455-zap...
# 14     CONVERSE   95.00  https://www.murallasport.com/producto/5587-zap...
# 15     CONVERSE  110.00  https://www.murallasport.com/producto/5387-zap...
# 16     CONVERSE  110.00  https://www.murallasport.com/producto/5388-zap...
# 17     CONVERSE  120.00  https://www.murallasport.com/producto/5927-zap...
# 18         VANS   64.00  https://www.murallasport.com/producto/5556-zap...
# 19         VANS   85.00  https://www.murallasport.com/producto/6047-van...
# 20         VANS   96.00  https://www.murallasport.com/producto/5566-zap...
# 21         PUMA   56.00  https://www.murallasport.com/producto/5581-zap...
# 22         PUMA   88.00  https://www.murallasport.com/producto/5754-zap...
# 23         PUMA   89.95  https://www.murallasport.com/producto/5749-zap...

# %% [markdown]
# ### 5. Drop un-wanted columns if they exist

# %%
murallas = murallas.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ### 4. Insert the `df` into your `shoes` database on SQL: use a **pandas method**. You'll need to pass some arguments: `name` & `con`

# %%
engine = create_engine(f'mysql+pymysql://root:{db_password}@localhost/shoes')

murallas.to_sql(name='shoes', con=engine, if_exists='replace', index=False)
# Out:
# 24

# %% [markdown]
# ### 5. From python, query the table back and call it `queried_df`

# %%
queried_df = pd.read_sql('SELECT * FROM shoes', con=engine)
queried_df
# Out:
#                                                 names        brand   price  \
# 0   Zapatilla Mujer Reebok Classic Leather SP   Bl...       ADIDAS   90.00
# 1               Zapatilla Nike Zoom Air Fire   Blanco         NIKE  119.99
# 2                                     New Balance 530  NEW BALANCE  110.00
# 3               Zapatillla  New Balance CT302   Beige  NEW BALANCE  110.00
# 4             Zapatilla Mujer New Balance 327   Beige  NEW BALANCE  114.00
# 5                                     New Balance 327  NEW BALANCE  120.00
# 6                                     New Balance 327  NEW BALANCE  120.00
# 7                                     New Balance 610  NEW BALANCE  120.00
# 8   Zapatilla  Converse All Star Lift High Water-R...     CONVERSE   79.95
# 9   Zapatilla  Converse All Star Hi Water-Repellen...     CONVERSE   80.00
# 10                   Zapatilla Converse Lift Hi Suede     CONVERSE   84.95
# 11      Zapatilla  Converse CTAS Lugged 2.0 Hi   Gris     CONVERSE   85.00
# 12  Zapatilla  Converse Chuck Taylor  Lift Hi  Marrón     CONVERSE   90.00
# 13  Zapatilla Mujer Converse Move Plat Stripe Knit...     CONVERSE   95.00
# 14  Zapatilla Converse Chuck Taylor All Star Lift ...     CONVERSE   95.00
# 15          Zapatilla Converse Run Star Hike Hi  Gris     CONVERSE  110.00
# 16       Zapatilla  Converse Run Star Hike Hi  Marrón     CONVERSE  110.00
# 17  Zapatilla Converse Lugged 2.0 Caunter Climate ...     CONVERSE  120.00
# 18                           Zapatilla Vans Old Skool         VANS   64.00
# 19                   Vans Old Skool Platform   Blanco         VANS   85.00
# 20               Zapatilla  Vans Sk8-Hi Mte-1   Negro         VANS   96.00
# 21            Zapatilla  Puma Carina Lift TW   Blanco         PUMA   56.00
# 22                     Zapatilla  Puma Mayze   Blanco         PUMA   88.00
# 23                 Zapatillas  Puma Rider FV   Blanco         PUMA   89.95
#
#                                                 links
# 0   https://www.murallasport.com/producto/5477-zap...
# 1   https://www.murallasport.com/producto/5998-zap...
# 2   https://www.murallasport.com/producto/6229-new...
# 3   https://www.murallasport.com/producto/5330-zap...
# 4   https://www.murallasport.com/producto/5473-zap...
# 5   https://www.murallasport.com/producto/5948-new...
# 6   https://www.murallasport.com/producto/5949-new...
# 7   https://www.murallasport.com/producto/6045-new...
# 8   https://www.murallasport.com/producto/5584-zap...
# 9   https://www.murallasport.com/producto/5853-zap...
# 10  https://www.murallasport.com/producto/5578-zap...
# 11  https://www.murallasport.com/producto/5586-zap...
# 12  https://www.murallasport.com/producto/5608-zap...
# 13  https://www.murallasport.com/producto/5455-zap...
# 14  https://www.murallasport.com/producto/5587-zap...
# 15  https://www.murallasport.com/producto/5387-zap...
# 16  https://www.murallasport.com/producto/5388-zap...
# 17  https://www.murallasport.com/producto/5927-zap...
# 18  https://www.murallasport.com/producto/5556-zap...
# 19  https://www.murallasport.com/producto/6047-van...
# 20  https://www.murallasport.com/producto/5566-zap...
# 21  https://www.murallasport.com/producto/5581-zap...
# 22  https://www.murallasport.com/producto/5754-zap...
# 23  https://www.murallasport.com/producto/5749-zap...

# %% [markdown]
# ### 6. Does it look okay? You may wantto get rid of the index. Re-run your code with another argument to prevent that from being created

# %%
queried_df = pd.read_sql('SELECT * FROM shoes', con=engine, index_col=None)

queried_df
# Out:
#                                                 names        brand   price  \
# 0   Zapatilla Mujer Reebok Classic Leather SP   Bl...       ADIDAS   90.00
# 1               Zapatilla Nike Zoom Air Fire   Blanco         NIKE  119.99
# 2                                     New Balance 530  NEW BALANCE  110.00
# 3               Zapatillla  New Balance CT302   Beige  NEW BALANCE  110.00
# 4             Zapatilla Mujer New Balance 327   Beige  NEW BALANCE  114.00
# 5                                     New Balance 327  NEW BALANCE  120.00
# 6                                     New Balance 327  NEW BALANCE  120.00
# 7                                     New Balance 610  NEW BALANCE  120.00
# 8   Zapatilla  Converse All Star Lift High Water-R...     CONVERSE   79.95
# 9   Zapatilla  Converse All Star Hi Water-Repellen...     CONVERSE   80.00
# 10                   Zapatilla Converse Lift Hi Suede     CONVERSE   84.95
# 11      Zapatilla  Converse CTAS Lugged 2.0 Hi   Gris     CONVERSE   85.00
# 12  Zapatilla  Converse Chuck Taylor  Lift Hi  Marrón     CONVERSE   90.00
# 13  Zapatilla Mujer Converse Move Plat Stripe Knit...     CONVERSE   95.00
# 14  Zapatilla Converse Chuck Taylor All Star Lift ...     CONVERSE   95.00
# 15          Zapatilla Converse Run Star Hike Hi  Gris     CONVERSE  110.00
# 16       Zapatilla  Converse Run Star Hike Hi  Marrón     CONVERSE  110.00
# 17  Zapatilla Converse Lugged 2.0 Caunter Climate ...     CONVERSE  120.00
# 18                           Zapatilla Vans Old Skool         VANS   64.00
# 19                   Vans Old Skool Platform   Blanco         VANS   85.00
# 20               Zapatilla  Vans Sk8-Hi Mte-1   Negro         VANS   96.00
# 21            Zapatilla  Puma Carina Lift TW   Blanco         PUMA   56.00
# 22                     Zapatilla  Puma Mayze   Blanco         PUMA   88.00
# 23                 Zapatillas  Puma Rider FV   Blanco         PUMA   89.95
#
#                                                 links
# 0   https://www.murallasport.com/producto/5477-zap...
# 1   https://www.murallasport.com/producto/5998-zap...
# 2   https://www.murallasport.com/producto/6229-new...
# 3   https://www.murallasport.com/producto/5330-zap...
# 4   https://www.murallasport.com/producto/5473-zap...
# 5   https://www.murallasport.com/producto/5948-new...
# 6   https://www.murallasport.com/producto/5949-new...
# 7   https://www.murallasport.com/producto/6045-new...
# 8   https://www.murallasport.com/producto/5584-zap...
# 9   https://www.murallasport.com/producto/5853-zap...
# 10  https://www.murallasport.com/producto/5578-zap...
# 11  https://www.murallasport.com/producto/5586-zap...
# 12  https://www.murallasport.com/producto/5608-zap...
# 13  https://www.murallasport.com/producto/5455-zap...
# 14  https://www.murallasport.com/producto/5587-zap...
# 15  https://www.murallasport.com/producto/5387-zap...
# 16  https://www.murallasport.com/producto/5388-zap...
# 17  https://www.murallasport.com/producto/5927-zap...
# 18  https://www.murallasport.com/producto/5556-zap...
# 19  https://www.murallasport.com/producto/6047-van...
# 20  https://www.murallasport.com/producto/5566-zap...
# 21  https://www.murallasport.com/producto/5581-zap...
# 22  https://www.murallasport.com/producto/5754-zap...
# 23  https://www.murallasport.com/producto/5749-zap...

# %% [markdown]
# ### 7. Now, from python, drop the database AND the table. Reminder: selecting & insertying use different methods. one uses **pandas** and the other one just the **engine**.

# %%
with engine.connect() as connection:
    connection.execute('DROP DATABASE IF EXISTS shoes')

# %% [markdown]
# ### 8. Get your code and create a function.

# %% [markdown]
# `Tip`: Queries through python should be created one by one

# %%
def load_into_db(schema, table_name, df):
    connection_string = f'mysql+pymysql://root:{db_password}@localhost/{schema}'

    engine = create_engine(connection_string)

    with engine.connect() as connection:
        connection.execute(f'DROP TABLE IF EXISTS {table_name}')

    df.to_sql(name=table_name, con=engine, if_exists='replace', index=False)

    with engine.connect() as connection:
        result = connection.execute(f'SELECT COUNT(*) FROM {table_name}')
        total_rows = result.fetchone()[0]

    feedback = f'{total_rows} rows have been inserted into the {schema}.{table_name} table.'
    return feedback

# %% [markdown]
# ### 9. Try to call the function more than once. Does it work? if so, success!
